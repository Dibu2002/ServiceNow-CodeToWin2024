# %%
# Go to the directory with requirements.txt
# %cd D:/ServiceNow_Code_to_Win/YOLOv8-DeepSORT-Object-Tracking
# Out:
# D:\ServiceNow_Code_to_Win\YOLOv8-DeepSORT-Object-Tracking

# %%
# Install Dependencies
! pip install -r requirements.txt

# %%
# Move to required Directory
# %cd /content/drive/MyDrive/serviceNow/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect
# Out:
# /content/drive/MyDrive/serviceNow/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect

# %% [markdown]
# Find dimensions of video frame to set the green line accordingly

# %%
video_path = '/content/drive/MyDrive/serviceNow/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect/cars2.mp4'

# %%
from cv2 import VideoCapture
cap = VideoCapture(video_path)
ret, frame = cap.read()
height, width, channels = frame.shape
print("Dimensions of the frame: {}x{}".format(width, height))
# Out:
# Dimensions of the frame: 1280x720

# %%
! python predict.py source=video_path
# Out:
# [2024-03-06 08:08:30,214][root.tracker][INFO] - Loading weights from deep_sort_pytorch/deep_sort/deep/checkpoint/ckpt.t7... Done!
# 2024-03-06 08:08:30.888057: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-06 08:08:30.888122: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-06 08:08:30.890386: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-06 08:08:32.636715: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU
# Fusing layers...
# ...

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/drive/MyDrive/serviceNow/YOLOv8-DeepSORT-Object-Tracking/runs/detect/train19/cars2.mp4'
